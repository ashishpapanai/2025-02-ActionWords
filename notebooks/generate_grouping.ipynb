# %%
import json
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics.pairwise import cosine_similarity

# %%
SIMILARITY_THRESHOLD = 0.85
MODEL_NAME = "all-MiniLM-L6-v2"

FILES = {
    "02": "../data_dump/variables/2002/ZA3880_variables_short.json",
    "12": "../data_dump/variables/2012/ZA5900_variables_short.json",
    "22": "../data_dump/variables/2022/ZA10000_variables_short.json",
}

def load_unique_questions(path):
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)
    q_to_var = {}
    for var, q in data.items():
        q = q.strip()
        if q not in q_to_var:
            q_to_var[q] = var
    return q_to_var

records = []
for year, path in FILES.items():
    qmap = load_unique_questions(path)
    for q, var in qmap.items():
        records.append({"year": year, "question": q, "var": var})

meta_df = pd.DataFrame(records)
model = SentenceTransformer(MODEL_NAME)
embeddings = model.encode(meta_df["question"].tolist(), normalize_embeddings=True)

cos_sim = cosine_similarity(embeddings)
distance = 1 - cos_sim

years = meta_df["year"].values

for i in range(len(distance)):
    for j in range(len(distance)):
        if i != j and years[i] == years[j]:
            if meta_df.iloc[i]["question"] != meta_df.iloc[j]["question"]:
                distance[i, j] = 1.0  

clustering = AgglomerativeClustering(
    metric="precomputed",
    linkage="average",
    distance_threshold=1 - SIMILARITY_THRESHOLD,
    n_clusters=None,
)

labels = clustering.fit_predict(distance)
meta_df["group"] = labels

rows = []

for gid, group in meta_df.groupby("group"):
    row = {
        "question": group.iloc[0]["question"],
        "question_02": "",
        "question_12": "",
        "question_22": "",
        "var_02": "",
        "var_12": "",
        "var_22": "",
        "similarity_score": cosine_similarity(model.encode(group["question"].tolist(), normalize_embeddings=True)).mean()}

    for _, r in group.iterrows():
        row[f"question_{r['year']}"] = r["question"]
        row[f"var_{r['year']}"] = r["var"]

    rows.append(row)

final_df = pd.DataFrame(rows)
final_df.to_csv("common_question_mapping.csv", index=False)

# %%
mapping_var = pd.read_csv("../data_dump/common_question_mapping.csv")
mapping_var
# Out:
#                                                    hh  \
# 0                      Place of living: urban - rural
# 1                           Top-Bottom self-placement
# 2                        Spouse, partner: main status
# 3                Spouse, partner: hours worked weekly
# 4                                                 SEX
# 5          Sample Prefix ISO 3166 Code - alphanumeric
# 6           Q4e Couple livg together without marriage
# 7          Q3c Shld women work:youngest kid at school
# 8          Q3b Shld women work:child under school age
# 9   Q32 Spouse, partner degree: Highest completed ...
# 10        Q2d Men should do larger share of childcare
# 11  Q2b Men's job earn money, women's job look aft...
# 12        Q24c Number of people in hh: kids up to 5,6
# 13       Q24b How many people in hh:kids 6,7 - 17 yrs
# 14        Q24a How many people in hh: adults 18 yrs +
# 15    Q23b Difficult to fulfill family responsibility
# 16                      Q22 Who has the higher income
# 17     Q20 Sharing of household work between partners
# 18  Q1e Working woman: Being housewife is as fulfi...
# 19          Q1d What women really want is home & kids
# 20               Q1c Workg woman: family life suffers
# 21            Q1b Workg mom: pre school child suffers
# 22  Q1a Working mom: warm relationship with childr...
# 23   Q19f Division of household work: Preparing meals
# 24  Q19e Division of household work: Household cle...
# 25  Q19d Division of household work: Shops for gro...
# 26  Q19c Division of household work: Care for sick...
# 27  Q19a Division of household work: Doing the lau...
# 28             Q18 Sharing of income between partners
# 29  Q17b How many hours spouse, partner spends on ...
# 30  Q17a How many hours spouse, partner works on h...
# 31        Q17 Life in general: how happy on the whole
# 32              Q16d Difficult to concentrate at work
# 33       Q16c Too tired from hhwork to function i job
# 34        Q16b How many hours spend on family members
# 35      Q16a Too tired from work to do duties at home
# 36        Q16a How many hours spend on household work
# 37        Q13a Final say: choosing weekend activities
# 38                                        Main status
# 39                       Living in steady partnership
# 40                           Legal partnership status
# 41                      How many persons in household
# 42                                Hours worked weekly
# 43  Highest completed degree of education: Categor...
# 44  Country/ Sample ISO 3166 Code (see V4 for code...
# 45                                  Age of respondent
# 46                                      Respondent ID
#
#                                           question_02  \
# 0   Type of community: urban-rural self-ass (URBRU...
# 1    R:Top Bottom self-placement 10 pt scale (TOPBOT)
# 2            S-P: Current employment status (SPWRKST)
# 3                     Q27 Spouse: hours worked weekly
# 4                                        R: Sex (SEX)
# 5          Sample Prefix ISO 3166 Code - alphanumeric
# 6           Q4e Couple livg together without marriage
# 7          Q3c Shld women work:youngest kid at school
# 8          Q3b Shld women work:child under school age
# 9            Q26 Spouse degree: highest qualification
# 10        Q2d Men should do larger share of childcare
# 11        Q2b Men's job is work,women's job household
# 12        Q24c Number of people in hh: kids up to 5,6
# 13       Q24b How many people in hh:kids 6,7 - 17 yrs
# 14        Q24a How many people in hh: adults 18 yrs +
# 15        Q16b Difficult to fulfil fam.responsibility
# 16                     Q14 Who has the higher income?
# 17        Q10 Sharing of hh work between the partners
# 18        Q1e Household satisfies as much as paid job
# 19          Q1d What women really want is home & kids
# 20               Q1c Workg woman: family life suffers
# 21            Q1b Workg mom: pre school child suffers
# 22              Q1a Workg mom: warm relation child ok
# 23          Q8f Division of hh work: preparg the meal
# 24               Q8e Division of hh work: hh cleaning
# 25          Q8d Division of hh work:shops f groceries
# 26           Q8c Div. hh work:care f sick fam.members
# 27         Q8a Division of hh work: doing the laundry
# 28                Q7 Organizing income in partnership
# 29                                                NaN
# 30        Q9b How many hrs spouse,partner works on hh
# 31        Q17 Life in general: how happy on the whole
# 32              Q16d Difficult to concentrate at work
# 33       Q16c Too tired from hhwork to function i job
# 34                                                NaN
# 35      Q16a Too tired from work to do duties at home
# 36         Q9a How many hours do you spend on hh work
# 37        Q13a Final say: choosing weekend activities
# 38               R: Current employment status (WRKST)
# 39                     R: Steady life-partner (COHAB)
# 40                        R: Marital status (MARITAL)
# 41             How many persons in household (HOMPOP)
# 42                    R: Hours worked weekly (WRKHRS)
# 43   R: Education II-highest education level (DEGREE)
# 44                         Country/ Sample (ISO 3166)
# 45                                       R: Age (AGE)
# 46                                  Respondent Number
#
#                                           question_12  \
# 0                      Place of living: urban - rural
# 1                           Top-Bottom self-placement
# 2                        Spouse, partner: main status
# 3                Spouse, partner: hours worked weekly
# 4                                   Sex of Respondent
# 5         Country Prefix ISO 3166 Code - alphanumeric
# 6   Q4c Marriage: Couple living together without m...
# 7       Q3b Should women work: Youngest kid at school
# 8       Q3a Should women work: Child under school age
# 9   Q32 Spouse, partner degree: Highest completed ...
# 10                                                NaN
# 11  Q2b Men's job earn money, women's job look aft...
# 12  How many toddlers in household: children up to...
# 13  How many children in household: children betwe...
# 14                                                NaN
# 15    Q23b Difficult to fulfill family responsibility
# 16                      Q22 Who has the higher income
# 17     Q20 Sharing of household work between partners
# 18  Q1e Working woman: Being housewife is as fulfi...
# 19  Q1d Working woman: What women really want is h...
# 20  Q1c Working woman: Family life suffers when wo...
# 21  Q1b Working mom: Preschool child is likely to ...
# 22  Q1a Working mom: warm relationship with childr...
# 23   Q19f Division of household work: Preparing meals
# 24  Q19e Division of household work: Household cle...
# 25  Q19d Division of household work: Shops for gro...
# 26  Q19c Division of household work: Care for sick...
# 27  Q19a Division of household work: Doing the lau...
# 28             Q18 Sharing of income between partners
# 29  Q17b How many hours spouse, partner spends on ...
# 30  Q17a How many hours spouse, partner works on h...
# 31        Q24 Life in general: How happy on the whole
# 32              Q23d Difficult to concentrate at work
# 33     Q23c Too tired from hh work to function in job
# 34        Q16b How many hours spend on family members
# 35      Q23a Too tired from work to do duties at home
# 36        Q16a How many hours spend on household work
# 37         Q21 Final say: Choosing weekend activities
# 38                                        Main status
# 39                       Living in steady partnership
# 40                           Legal partnership status
# 41                      How many persons in household
# 42                                Hours worked weekly
# 43  Highest completed degree of education: Categor...
# 44  Country/ Sample ISO 3166 Code (see V4 for code...
# 45                                  Age of respondent
# 46                            ID Number of Respondent
#
#                                           question_22    var_02    var_12  \
# 0                      Place of living: urban - rural      V358  URBRURAL
# 1                           Top-Bottom self-placement      V291    TOPBOT
# 2                        Spouse, partner: main status      V246  SPMAINST
# 3                Spouse, partner: hours worked weekly       V71  SPWRKHRS
# 4                                   Sex of Respondent      V200       SEX
# 5   Country/ Sample Prefix ISO 3166 code - alphanu...  C_ALPHAN  C_ALPHAN
# 6      Q4d Couple living together without marriage ok       V22       V16
# 7       Q3b Should women work: youngest kid at school       V16       V13
# 8       Q3a Should women work: child under school age       V15       V12
# 9   ISCED 2011 simplified: highest completed degre...       V70       V65
# 10  Q2b Mother or father better suited to look aft...       V13       NaN
# 11  Q1f Men's job earn money, women's job look aft...       V11       V11
# 12    How many children below school age in household       V67    HHTODD
# 13  How many children above school entry age in ho...       V66  HHCHILDR
# 14                       How many adults in household       V65       NaN
# 15  Q20b Difficult to fulfill family responsibilities       V49       V52
# 16                                                NaN       V43       V50
# 17     Q19 Sharing of household work between partners       V38       V48
# 18  Q1e Being housewife is as fulfilling as workin...        V8        V9
# 19        Q1d What women really want is home and kids        V7        V8
# 20  Q1c Family life suffers when woman has full-ti...        V6        V7
# 21  Q1b Pre-school child is likely to suffer if mo...        V5        V6
# 22  Q1a Working mom can establish as warm relation...        V4        V5
# 23   Q18f Division of household work: preparing meals       V35       V47
# 24  Q18e Division of household work: household cle...       V34       V46
# 25  Q18d Division of household work: shops for gro...       V33       V45
# 26  Q18c Division of household work: care for sick...       V32       V44
# 27  Q18a Division of household work: doing the lau...       V30       V42
# 28             Q17 Sharing of income between partners       V29       V41
# 29  Q16b How many hrs spouse, partner spends on fa...       NaN       V40
# 30  Q16a How many hours spouse, partner works on h...       V37       V39
# 31        Q26 Life in general: how happy on the whole       V52       V55
# 32              Q20d Difficult to concentrate at work       V51       V54
# 33  Q20c Too tired from household work to function...       V50       V53
# 34        Q15b How many hours spend on family members       NaN       V38
# 35      Q20a Too tired from work to do duties at home       V48       V51
# 36        Q15a How many hours spend on household work       V36       V37
# 37  Q18b Division of household work: plan social/f...       V41       V49
# 38                                        Main status      V239  MAINSTAT
# 39                       Living in steady partnership      V203   PARTLIV
# 40                           Legal partnership status      V202   MARITAL
# 41                      How many persons in household      V251    HOMPOP
# 42                                Hours worked weekly      V240    WRKHRS
# 43  ISCED 2011 simplified: highest completed degre...      V205    DEGREE
# 44  Country/ Sample ISO 3166 code (see country for...   COUNTRY        V3
# 45                                  Age of respondent      V201       AGE
# 46                            ID Number of Respondent        v3    CASEID
#
#       var_22  score           COMMON_VAR
# 0   URBRURAL  1.000          urban_rural
# 1     TOPBOT  1.000               TOPBOT
# 2   SPMAINST  1.000   spouse_work_status
# 3   SPWRKHRS  1.000             SPWRKHRS
# 4        SEX  1.000                  sex
# 5   c_alphan  0.938             C_ALPHAN
# 6        v14  0.944             LIVWOMAR
# 7        v10  0.944                WWYKS
# 8         v9  0.948               WWYKUS
# 9   SPEDULEV  1.000            SP_DEGREE
# 10        v8  1.000             MOMORFAF
# 11        v6  0.965                 MEWH
# 12    HHTODD  1.000               HHTODD
# 13  HHCHILDR  1.000             HHCHILDR
# 14   HHADULT  1.000              HHADULT
# 15       V47  1.000              FAM_DIF
# 16       NaN  1.000   code_higher_income
# 17       v45  0.963             SHARE_HH
# 18        v5  0.964            HW_FULFIL
# 19        v4  0.957              WO_WANT
# 20        v3  0.931        WW_FAM_SUFFER
# 21        v2  0.930      WW_CHILD_SUFFER
# 22        v1  0.958              WW_WARM
# 23       v44  0.968          DIV_HH_COOK
# 24       v43  0.973         DIV_HH_CLEAN
# 25       v42  0.971          DIV_HH_GROC
# 26       v41  0.983          DIV_HH_CARE
# 27       v39  0.971         DIV_HH_LAUND
# 28       v38  0.961  code_income_control
# 29       v37  0.947            SP_HH_FAM
# 30       v36  0.977                SP_HH
# 31       v56  0.919             LIFE_HAP
# 32       v49  0.921       DIFF_CONC_WORK
# 33       V48  0.926             HH_TIRED
# 34       v35  0.978               HH_FAM
# 35       v46  0.910           WORK_TIRED
# 36       v34  0.976           hh_wrk_hrs
# 37       V40  0.980           HH_WEEKEND
# 38  MAINSTAT  1.000          work_status
# 39   PARTLIV  1.000                COHAB
# 40   MARITAL  1.000              marital
# 41    HOMPOP  1.000               HOMPOP
# 42    WRKHRS  1.000              wrk_hrs
# 43  EDULEVEL  1.000    highest_education
# 44  c_sample  0.992              COUNTRY
# 45       AGE  1.000                  age
# 46    CASEID    NaN               CASEID

# %%
var_02_map = {}
var_12_map = {}
var_22_map = {}

for row in mapping_var.itertuples():
    common_var = row.COMMON_VAR
    var_02_map[row.var_02] = common_var
    var_12_map[row.var_12] = common_var
    var_22_map[row.var_22] = common_var

# %%
with open("../data_dump/var_02_map.json", "w", encoding="utf-8") as f:
    json.dump(var_02_map, f, indent=4)

with open("../data_dump/var_12_map.json", "w", encoding="utf-8") as f:
    json.dump(var_12_map, f, indent=4)  

with open("../data_dump/var_22_map.json", "w", encoding="utf-8") as f:
    json.dump(var_22_map, f, indent=4)
